# %%
import matplotlib.pyplot as plt
import numpy as np
import imageio
import skimage.color

img = imageio.imread('10_21_data_tiffs\\Cow_35\\49_D.tif')
img = img/np.max(img)*255

plt.figure()
plt.imshow(img, cmap = 'jet')

plt.figure()
plt.imshow(skimage.color.gray2rgb(img.astype('uint8')))

imageio.imwrite('masks\\Jornada_lane_mask_big.png', skimage.color.gray2rgb(img.astype('uint8')), 'PNG')
